# %% [markdown]
# # Comparing 2 means in 4 different ways - part 1
#
# In this example, we will compare method A and method B of our industrial experiment in 4 ways
#
# 1. external reference distribution
# 2. external reference distribution + t test
# 3. random sampling assumption, with external value for σ
# 4. random sampling assumption, with internal estimate for σ

# %% [markdown]
# ## Method 1: using external reference distribution
#
# We have 10 data points for method A and 10 data points for method B.
#
# The means are different: 84.24 for method A vs. 85.54 for method B.
#
# The reference distribution has 210 data points with a mean of 84.12
#
# Question: are 84.24 and 85.54 statistically different based on the reference distribution?
#
# To answer, we will compare the 1.30 difference (85.54-84.24) to a reference set of differences between averages of adjacent sets of 10 successive batches. We color in red the differences that exceed +1.30

# %%
import pandas as pd
import numpy as np
# %config Completer.use_jedi = False
pd.set_option('display.max_rows', 500)
y_210 = pd.read_excel('yield 210.xlsx')
y_AB = pd.read_excel('yield 20.xlsx')

# %%
lambda_ma = lambda x: y_210.iloc[x-9:x+1,0].mean() - y_210.iloc[x-19:x-9,0].mean() if x >= 19 else None
y_210['diff_ma'] = y_210['yield'].index.map(lambda_ma)
y_210.style.applymap(lambda x: 'color:red' if x > 1.3 else '', subset=['diff_ma'])
# Out:
# <style  type="text/css" >
#     #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow41_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow42_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow43_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow45_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow71_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow74_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow75_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow138_col1 {
#             color: red;
#         }    #T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow205_col1 {
#             color: red;
#         }</style><table id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >yield</th>        <th class="col_heading level0 col1" >diff_ma</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow0_col0" class="data row0 col0" >85.500000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow0_col1" class="data row0 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow1_col0" class="data row1 col0" >81.700000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow1_col1" class="data row1 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow2_col0" class="data row2 col0" >80.600000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow2_col1" class="data row2 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow3_col0" class="data row3 col0" >84.700000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow3_col1" class="data row3 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow4_col0" class="data row4 col0" >88.200000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow4_col1" class="data row4 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow5_col0" class="data row5 col0" >84.900000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow5_col1" class="data row5 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow6_col0" class="data row6 col0" >81.800000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow6_col1" class="data row6 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow7_col0" class="data row7 col0" >84.900000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow7_col1" class="data row7 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow8_col0" class="data row8 col0" >85.200000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow8_col1" class="data row8 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow9_col0" class="data row9 col0" >81.900000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow9_col1" class="data row9 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow10_col0" class="data row10 col0" >89.400000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow10_col1" class="data row10 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow11_col0" class="data row11 col0" >79.000000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow11_col1" class="data row11 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow12_col0" class="data row12 col0" >81.400000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow12_col1" class="data row12 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow13_col0" class="data row13 col0" >84.800000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow13_col1" class="data row13 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow14_col0" class="data row14 col0" >85.900000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow14_col1" class="data row14 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow15_col0" class="data row15 col0" >88.000000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow15_col1" class="data row15 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow16_col0" class="data row16 col0" >80.300000</td>
#                         <td id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fcrow16_col1" class="data row16 col1" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_9fe68122_7559_11ec_8029_d8f2ca0a25fclevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_9fe68122_7559_11ec_8029_d8

# %%
#isolating data points for which difference exceeds +1.30
y_210[y_210['diff_ma'] > 1.3].style.applymap(lambda x: 'color:red')
# Out:
# <style  type="text/css" >
#     #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow0_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow0_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow1_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow1_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow2_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow2_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow3_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow3_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow4_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow4_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow5_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow5_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow6_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow6_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow7_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow7_col1 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow8_col0 {
#             color: red;
#         }    #T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow8_col1 {
#             color: red;
#         }</style><table id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >yield</th>        <th class="col_heading level0 col1" >diff_ma</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row0" class="row_heading level0 row0" >41</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow0_col0" class="data row0 col0" >82.400000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow0_col1" class="data row0 col1" >1.470000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row1" class="row_heading level0 row1" >42</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow1_col0" class="data row1 col0" >86.700000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow1_col1" class="data row1 col1" >1.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row2" class="row_heading level0 row2" >43</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow2_col0" class="data row2 col0" >83.000000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow2_col1" class="data row2 col1" >2.480000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row3" class="row_heading level0 row3" >45</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow3_col0" class="data row3 col0" >89.300000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow3_col1" class="data row3 col1" >1.330000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row4" class="row_heading level0 row4" >71</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow4_col0" class="data row4 col0" >90.500000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow4_col1" class="data row4 col1" >1.460000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row5" class="row_heading level0 row5" >74</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow5_col0" class="data row5 col0" >86.500000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow5_col1" class="data row5 col1" >1.350000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row6" class="row_heading level0 row6" >75</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow6_col0" class="data row6 col0" >90.000000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow6_col1" class="data row6 col1" >1.370000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row7" class="row_heading level0 row7" >138</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow7_col0" class="data row7 col0" >83.200000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow7_col1" class="data row7 col1" >1.870000</td>
#             </tr>
#             <tr>
#                         <th id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fclevel0_row8" class="row_heading level0 row8" >205</th>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow8_col0" class="data row8 col0" >83.300000</td>
#                         <td id="T_9ff7399e_7559_11ec_94c3_d8f2ca0a25fcrow8_col1" class="data row8 col1" >1.390000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# There are only 9 differences that exceed 1.30, out of the 191 differences between consecutive averages of 10 batches.
# The level of statistical significance is 9/191 = 0.047.
#
# What this means is that roughly 5 times out of 100, we can expect the difference to exceed +1.30, in normal operations, which is quite rare.
#
# Therefore, our observation of +1.30 is probably not due to pure chance. There appears to be a difference between method A and method B.
#
# The advantages of a reference set are clear. We do not need to make any assumptions about the distribution of the observed data. We just compare it to the reference and compute the probability to have obtained such a result in the reference distribution.
